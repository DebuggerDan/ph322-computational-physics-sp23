# %% [markdown]
# ## Homework 3
#
#
# * Note use the *vpython* module not the *visual* module for Exercise 3.5. Put the *canvas()* at the beginning of your program to create a graphics window.
#
# Name: Dan Jang
#
# Comments for grader:

# %% [markdown]
# ## Exercise 3.5
#
#  The innermost six planets of our solar system revolve around the
# Sun in roughly circular orbits that all lie approximately in the same
# (ecliptic) plane.  Here are some basic parameters:
#
# ![image.png](attachment:image.png)
#
# Using *vpython* functions, create an
# animation of the solar system that shows the following:
#
# **a)** The Sun and planets as spheres in their appropriate positions and
#   with sizes proportional to their actual sizes.  Because the radii of the
#   planets are tiny compared to the distances between them, represent the
#   planets by spheres with radii $c_1$ times larger than their correct
#   proportionate values, so that you can see them clearly.  Find a good
#   value for $c_1$ that makes the planets visible.  You'll also need to find
#   a good radius for the Sun.  Choose any value that gives a clear
#   visualization.  (It doesn't work to scale the radius of the Sun by the
#   same factor you use for the planets, because it'll come out looking much
#   too large.  So just use whatever works.)  For added realism, you may also
#   want to make your spheres different colors.  For instance, Earth could be
#   blue and the Sun could be yellow.
#
#   Hints:
#
# - Calculate a scale factor that maps the planet orbits onto your *canvas()* frame, e.g. make the diameter of the largest planetary orbit span ~90% of the frame. Multiply this scale factor by $c_1$ to set the planet radii.
# - You may find it useful to store the sphere variables representing the planets in an array of the kind described on page 115.
# - I find a value $c_1 = 2000$ works.
# - For even more realism you can add [textures](https://www.glowscript.org/docs/VPythonDocs/textures.html) to the planets to create realistic looking surfaces.

# %%
#### PH 322 - HW #3, Q3.5a) - Dan Jang
### Credits to ChatGPT for numpy-code & vpython implementation help

from vpython import *
import numpy as np

## Constants in SI units
G = 6.6743e-11  # Gravitational constant
Msun = 1.989e30  # Mass of Sun in kg
AU = 149.6e6 * 1000  # Astronomical Unit in m

## Define planet data
planet_data = {
    "Mercury": {"radius": 2440e3, "orbit_radius": 57.9e6 * AU, "period": 88.0},
    "Venus": {"radius": 6052e3, "orbit_radius": 108.2e6 * AU, "period": 224.7},
    "Earth": {"radius": 6371e3, "orbit_radius": 149.6e6 * AU, "period": 365.3},
    "Mars": {"radius": 3386e3, "orbit_radius": 227.9e6 * AU, "period": 687.0},
    "Jupiter": {"radius": 69173e3, "orbit_radius": 778.5e6 * AU, "period": 4331.6},
    "Saturn": {"radius": 57316e3, "orbit_radius": 1433.4e6 * AU, "period": 10759.2},
    "Sun": {"radius": 695500e3, "orbit_radius": 0, "period": 0}
}

## Set up scene
scene = canvas(title="Solar System", width=800, height=600)

## Calculate scale factor to map planet orbits onto canvas
orbit_radii = [planet_data[planet]["orbit_radius"] for planet in planet_data]
orbit_scale = 0.9 * scene.width / (2 * max(orbit_radii))

## Create Sun
sun_radius = 50  # arbitrary value that works well visually
sun = sphere(pos=vec(0, 0, 0), radius=sun_radius, color=color.yellow)

## Create planets
planets = np.empty(len(planet_data), dtype=object)
for i, planet in enumerate(planet_data):
    radius = planet_data[planet]["radius"] / orbit_scale
    pos = vec(planet_data[planet]["orbit_radius"] / orbit_scale, 0, 0)
    period = planet_data[planet]["period"]
    planet_color = color.white if planet != "Sun" else color.yellow
    planets[i] = sphere(pos=pos, radius=radius, color=planet_color)
    planets[i].trail = curve(color=planet_color, radius=radius / 20)
    
## Run simulation
t = 0
dt = 3600 * 24  # time step of 1 day
while True:
    rate(100)
    for planet in planet_objects:
        r = planet.pos - Sun.pos
        F = (-G * Msun * planet.m / mag(r) ** 2) * norm(r)
        planet.v += (F / planet.m) * dt
        planet.pos += planet.v * dt
# Out:
# <div id="glowscript" class="glowscript"></div>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[37], line 51
#      49 for planet in planet_objects:
#      50     r = planet.pos - Sun.pos
# ---> 51     F = (-G * Sun.m * planet.m / mag(r) ** 2) * norm(r)
#      52     planet.v += (F / planet.m) * dt
#      53     planet.pos += planet.v * dt
#
# AttributeError: 'sphere' object has no attribute 'm'

# %% [markdown]
# **/10 pts**

# %% [markdown]
# **b)** The motion of the planets as they move around the Sun (by making the
#   spheres of the planets move).  In the interests of alleviating boredom,
#   construct your program so that time in your animation runs a factor of
#   $c_2$ faster than actual time.  Find a good value of $c_2$ that makes the
#   motion of the orbits easily visible but not unreasonably fast.  Make use
#   of the *rate* function to make your animation run smoothly.

# %%
#### PH 322 - HW #3, Q3.5a) - Dan Jang
### Credits to ChatGPT for numpy-code & vpython implementation help

from vpython import *
import math

# Create a canvas
scene = canvas(width=800, height=600)

# Define physical parameters
G = 6.7e-11  # gravitational constant
AU = 1.5e11  # astronomical unit
day = 24 * 3600  # length of day in seconds
year = 365.25 * day  # length of year in seconds

# Define planetary parameters
# [mass (kg), distance from Sun (km), radius (km), period (s)]
planets = {
    "Sun": [1.989e30, 0, 696340, 0],
    "Mercury": [3.3e23, 57.9e6, 2439.7, 88 * day],
    "Venus": [4.87e24, 108.2e6, 6051.8, 225 * day],
    "Earth": [5.97e24, 149.6e6, 6371.0, 1 * year],
    "Mars": [6.42e23, 227.9e6, 3389.5, 1.9 * year],
    "Jupiter": [1.898e27, 778.3e6, 69911, 11.9 * year],
    "Saturn": [5.68e26, 1427.0e6, 58232, 29.5 * year],
    "Uranus": [8.68e25, 2871.0e6, 25362, 84.0 * year],
    "Neptune": [1.02e26, 4495.1e6, 24622, 165.0 * year],
}

# Set up the scene
scene.camera.pos = vector(0, -3000e3, 1e8)
scene.camera.axis = -scene.camera.pos
scene.range = 5 * AU
scene.background = color.black

# Create the Sun
Sun = sphere(
    pos=vector(0, 0, 0),
    radius=planets["Sun"][2] * 1000,
    color=color.yellow,
    emissive=True,
    m=1.989e30,
)

# Create the planets
planet_objects = []
for name, data in planets.items():
    if name == "Sun":
        continue
    mass, distance, radius, period = data
    planet = sphere(
        pos=vector(distance * 1000, 0, 0),
        radius=radius * 1000,
        color=color.white,
        make_trail=True,
    )
    planet.m = mass
    planet.v = vector(0, math.sqrt(G * Sun.m / (distance * 1000)), 0)
    planet_objects.append(planet)

# Define the time step
dt = 3600

# Set up the animation
while True:
    rate(100)
    for planet in planet_objects:
        r = planet.pos - Sun.pos
        F = (-G * Sun.m * planet.m / mag(r) ** 2) * norm(r)
        planet.v += (F / planet.m) * dt
        planet.pos += planet.v * dt
# Out:
# <div id="glowscript" class="glowscript"></div>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 66
#      64 # Set up the animation
#      65 while True:
# ---> 66     rate(100)
#      67     for planet in planet_objects:
#      68         r = planet.pos - Sun.pos
#
# File c:\tools\miniconda3\lib\site-packages\vpython\rate_control.py:266, in _RateKeeper2.__call__(self, N)
#     264 self.rval = N
#     265 if self.rval < 1: raise ValueError("rate value must be greater than or equal to 1")
# --> 266 super(_RateKeeper2, self).__call__(self.rval)
#
# File c:\tools\miniconda3\lib\site-packages\vpython\rate_control.py:220, in RateKeeper.__call__(self, maxRate)
#     217 # Determine how much time is left before the next predicted call to rate:
#     218 dt = self.lastSleep + self.calls*(self.userTime + self.callTime + self.delay) + \
#     219      renders*self.renderTime + sleeps*self.interactionPeriod - _clock()
# --> 220 _sleep(dt)
#     221 self.lastSleep = _clock()
#     222 self.calls = 0
#
# File c:\tools\miniconda3\lib\site-packages\vpython\rate_control.py:62, in _sleep(dt)
#      60 dtsleep = nticks*_tick
#      61 t = _clock()
# ---> 62 time.sleep(dtsleep)
#      63 t = _clock()-t
#      64 dt -= t
#
# KeyboardInterrupt:

# %% [markdown]
# **/5 pts**

# %% [markdown]
# **Total Exercise Pts /15**

# %%
from vpython import *
import numpy as np

## Constants in SI units
G = 6.6743e-11  # Gravitational constant
Msun = 1.989e30  # Mass of Sun in kg
AU = 149.6e6 * 1000  # Astronomical Unit in m

## Define planet data
planet_data = {
    "Mercury": {"radius": 2440e3, "orbit_radius": 57.9e6 * AU, "period": 88.0},
    "Venus": {"radius": 6052e3, "orbit_radius": 108.2e6 * AU, "period": 224.7},
    "Earth": {"radius": 6371e3, "orbit_radius": 149.6e6 * AU, "period": 365.3},
    "Mars": {"radius": 3386e3, "orbit_radius": 227.9e6 * AU, "period": 687.0},
    "Jupiter": {"radius": 69173e3, "orbit_radius": 778.5e6 * AU, "period": 4331.6},
    "Saturn": {"radius": 57316e3, "orbit_radius": 1433.4e6 * AU, "period": 10759.2},
    "Sun": {"radius": 695500e3, "orbit_radius": 0, "period": 0}
}

## Set up scene
scene = canvas(title="Solar System", width=800, height=600)

## Calculate scale factor to map planet orbits onto canvas
orbit_radii = [planet_data[planet]["orbit_radius"] for planet in planet_data]
orbit_scale = 0.9 * scene.width / (2 * max(orbit_radii))

## Create Sun
sun_radius = 50  # arbitrary value that works well visually
sun = sphere(pos=vec(0, 0, 0), radius=sun_radius, color=color.yellow)

## Create planets
planets = np.empty(len(planet_data), dtype=object)
for i, planet in enumerate(planet_data):
    radius = planet_data[planet]["radius"] / orbit_scale
    pos = vec(planet_data[planet]["orbit_radius"] / orbit_scale, 0, 0)
    period = planet_data[planet]["period"]
    color = color.white if planet != "Sun" else color.yellow
    planets[i] = sphere(pos=pos, radius=radius, color=color)
    planets[i].trail = curve(color=color, radius=radius / 20)
    
## Run simulation
t = 0
dt = 3600 * 24  # time step of 1 day
while True:
    rate(1000)
    for i, planet in enumerate(planet_data):
        if planet == "Sun":
            continue
        r = planets[i].pos
        r_mag = np.linalg.norm(r)
        v_mag = np.sqrt(G * Msun / r_mag)
        v = vec(0, v_mag, 0)
        a = -G * Msun * r / r_mag**3
        planets[i].trail.append(pos=planets[i].pos)
        planets[i].pos += v * dt
        v += a * dt
        planets[i].pos += v * dt
    t += dt

# %% [markdown]
# ## Exercise 4.3
#
# Suppose we have a function $f(x)$ and we want to
# calculate its derivative at a point $x$.  We can do that with pencil and
# paper if we know the mathematical form of the function, or we can do it on
# the computer by making use of the definition of the derivative:
#
# \begin{equation*}
# { df\over dx} = \lim_{\delta\to0} {f(x+\delta)-f(x)\over\delta}.
# \end{equation*}
#
# On the computer we can't actually take the limit as $\delta$ goes to
# zero, but we can get a reasonable approximation just by making $\delta$
# small.
#
# **a)** Write a program that defines a function _f(x)_ returning the
#   value $x(x-1)$, then calculates the derivative of the function at the
#   point $x=1$ using the formula above with $\delta=10^{-2}$.

# %%
#### PH 322 - HW #3, Q4.3a&b) - Dan Jang
### Credits to ChatGPT for math-code implementation help

## Constants
x = 1  # Point at which to calculate the derivative
delta = 10e-2

# Definition of the to-be-derivative function
def f(x):
    return x*(x - 1)  # Example function: f(x) = x^2

# The derivative calculation function
def derivative(f, x, delta):
    return (f(x + delta) - f(x - delta)) / (2 * delta)

def main():
    approx_derivative = derivative(f, x, delta)
    print("The approximate derivative of f(x) at x = " + str(x) + " & delta = " + str(delta) + " was found to be: " + str(approx_derivative))

    ## Output statements for Q4.3b.

    print("[For Q4.3b, #1] - The approximate derivative of f(x) at x = " + str(x) + " & delta = " + "10e-4" + " was found to be: " + str(derivative(f, x, 10e-4)))
    print("[For Q4.3b, #2] - The approximate derivative of f(x) at x = " + str(x) + " & delta = " + "10e-6" + " was found to be: " + str(derivative(f, x, 10e-6)))
    print("[For Q4.3b, #3] - The approximate derivative of f(x) at x = " + str(x) + " & delta = " + "10e-8" + " was found to be: " + str(derivative(f, x, 10e-8)))
    print("[For Q4.3b, #4] - The approximate derivative of f(x) at x = " + str(x) + " & delta = " + "10e-10" + " was found to be: " + str(derivative(f, x, 10e-10)))
    print("[For Q4.3b, #5] - The approximate derivative of f(x) at x = " + str(x) + " & delta = " + "10e-12" + " was found to be: " + str(derivative(f, x, 10e-12)))
    print("[For Q4.3b, #6] - The approximate derivative of f(x) at x = " + str(x) + " & delta = " + "10e-14" + " was found to be: " + str(derivative(f, x, 10e-14)))

if __name__ == "__main__":
    main();
# Out:
# The approximate derivative of f(x) at x = 1 & delta = 0.1 was found to be: 1.0000000000000004
# [For Q4.3b, #1] - The approximate derivative of f(x) at x = 1 & delta = 10e-4 was found to be: 0.9999999999999454
# [For Q4.3b, #2] - The approximate derivative of f(x) at x = 1 & delta = 10e-6 was found to be: 1.000000000001
# [For Q4.3b, #3] - The approximate derivative of f(x) at x = 1 & delta = 10e-8 was found to be: 1.0000000000287559
# [For Q4.3b, #4] - The approximate derivative of f(x) at x = 1 & delta = 10e-10 was found to be: 1.0000000272292198
# [For Q4.3b, #5] - The approximate derivative of f(x) at x = 1 & delta = 10e-12 was found to be: 1.000000082740371
# [For Q4.3b, #6] - The approximate derivative of f(x) at x = 1 & delta = 10e-14 was found to be: 0.9997558336749534

# %% [markdown]
# **Estimated value of derivative:**  1.0000000000000004

# %% [markdown]
# Calculate the true value of the same derivative analytically and compare with the answer your program gives.  The two will not agree perfectly.  Why not?

# %% [markdown]
# **True value of derivative:** 1
#
# **Explanation:**

# %% [markdown]
# There is a refactoring of the pre-derivative function where f(x) = x(x - 1) = x^2 - x. Then, derivating that yields 2x - 1. Plugging in x = 1 yields an exact value of 1.
#
# Comparing this with the very close but not exactly equal estimated value above, such is because the estimated value is calculated by taking the limit of the derivative as delta approaches 0.
#
# However, since we instead use a specific delta value,10e-2, which is not exactly 0, the estimated value does not exactly equal to the true value.

# %% [markdown]
# **Pts /5**

# %% [markdown]
# **b)** Repeat the calculation for $\delta=10^{-4}$, $10^{-6}$, $10^{-8}$,
#   $10^{-10}$, $10^{-12}$, and $10^{-14}$.  Have your program output the derivative for each. Record derivatives in table below. You should see that the accuracy of the calculation initially gets better as $\delta$ gets smaller, but
#   then gets worse again.  Why is this?

# %% [markdown]
#
# |delta|f'(1)|
# |:----|-----:|
# |1e-4|0.9999999999999454|
# |1e-6|1.000000000001|
# |1e-8|1.0000000000287559|
# |1e-10|1.0000000272292198|
# |1e-12|1.000000082740371|
# |1e-14|0.9997558336749534|
#
#
# **Explanation:**

# %% [markdown]
# **Pts /5**

# %% [markdown]
# **Total Exercise Pts /10**

# %% [markdown]
# ## Exercise 5.3
#
# Consider the integral
#
# \begin{equation*}
# E(x) = \int_0^x e^{-t^2} \>d t.
# \end{equation*}
#
# **a)** Write a program to calculate $E(x)$ for values of $x$ from 0 to 3 in
#   steps of 0.1 using the **trapezoidal rule** and 20 slices.

# %%
#### PH 322 - HW #3, Q5.3a) - Dan Jang
### Credits to ChatGPT for math-code implementation help

## Libraries
import numpy as np

def f(t):
    return np.exp(-t**2)

def trapezoidal_integration(f, a, b, n):
    h = (b - a) / n
    x = np.linspace(a, b, n + 1)
    y = f(x)
    return h * (np.sum(y) - (y[0] + y[-1]) / 2)

def main():
    ## Constants
    n = 20
    a = 0
    b_values = np.arange(0, 3.1, 0.1)  # Values of x from 0 to 3 in steps of 0.1

    for b in b_values:
        E_x = trapezoidal_integration(f, a, b, n)
        print(f"Trapezoidal: E({b:.1f}) = {E_x:.6f}")

if __name__ == "__main__":
    main()
# Out:
# Trapezoidal: E(0.0) = 0.000000
# Trapezoidal: E(0.1) = 0.099667
# Trapezoidal: E(0.2) = 0.197362
# Trapezoidal: E(0.3) = 0.291228
# Trapezoidal: E(0.4) = 0.379630
# Trapezoidal: E(0.5) = 0.461240
# Trapezoidal: E(0.6) = 0.535091
# Trapezoidal: E(0.7) = 0.600598
# Trapezoidal: E(0.8) = 0.657557
# Trapezoidal: E(0.9) = 0.706106
# Trapezoidal: E(1.0) = 0.746671
# Trapezoidal: E(1.1) = 0.779896
# Trapezoidal: E(1.2) = 0.806574
# Trapezoidal: E(1.3) = 0.827574
# Trapezoidal: E(1.4) = 0.843780
# Trapezoidal: E(1.5) = 0.856040
# Trapezoidal: E(1.6) = 0.865134
# Trapezoidal: E(1.7) = 0.871748
# Trapezoidal: E(1.8) = 0.876464
# Trapezoidal: E(1.9) = 0.879760
# Trapezoidal: E(2.0) = 0.882020
# Trapezoidal: E(2.1) = 0.883540
# Trapezoidal: E(2.2) = 0.884541
# Trapezoidal: E(2.3) = 0.885188
# Trapezoidal: E(2.4) = 0.885599
# Trapezoidal: E(2.5) = 0.885854
# Trapezoidal: E(2.6) = 0.886009
# Trapezoidal: E(2.7) = 0.886102
# Trapezoidal: E(2.8) = 0.886157
# Trapezoidal: E(2.9) = 0.886188
# Trapezoidal: E(3.0) = 0.886206

# %% [markdown]
# **Pts /5**

# %% [markdown]
# **b)** Now repeat part *a* but now calculate the integral using **Simpson's rule** also using 20 slices.

# %%
#### PH 322 - HW #3, Q5.3b) - Dan Jang
### Credits to ChatGPT for math-code implementation help

## Libraries
import numpy as np


def f(t):
    return np.exp(-t**2)

def simpsons_rule_integration(f, a, b, n):
    if n % 2 == 1:
        raise ValueError("Number of slices must be even for Simpson's rule.")
    h = (b - a) / n
    x = np.linspace(a, b, n + 1)
    y = f(x)
    return h / 3 * (y[0] + y[-1] + 2 * np.sum(y[2:-1:2]) +
                    4 * np.sum(y[1:-1:2]))

def main():
    ## Constants
    n = 20
    a = 0
    b_values = np.arange(0, 3.1, 0.1)  # Values of x from 0 to 3 in steps of 0.1

    for b in b_values:
        E_x = simpsons_rule_integration(f, a, b, n)
        print(f"Simpson\'s: E({b:.1f}) = {E_x:.6f}")


if __name__ == "__main__":
    main()
# Out:
# Simpson's: E(0.0) = 0.000000
# Simpson's: E(0.1) = 0.099668
# Simpson's: E(0.2) = 0.197365
# Simpson's: E(0.3) = 0.291238
# Simpson's: E(0.4) = 0.379653
# Simpson's: E(0.5) = 0.461281
# Simpson's: E(0.6) = 0.535154
# Simpson's: E(0.7) = 0.600686
# Simpson's: E(0.8) = 0.657670
# Simpson's: E(0.9) = 0.706242
# Simpson's: E(1.0) = 0.746824
# Simpson's: E(1.1) = 0.780061
# Simpson's: E(1.2) = 0.806745
# Simpson's: E(1.3) = 0.827743
# Simpson's: E(1.4) = 0.843941
# Simpson's: E(1.5) = 0.856188
# Simpson's: E(1.6) = 0.865266
# Simpson's: E(1.7) = 0.871861
# Simpson's: E(1.8) = 0.876558
# Simpson's: E(1.9) = 0.879837
# Simpson's: E(2.0) = 0.882081
# Simpson's: E(2.1) = 0.883586
# Simpson's: E(2.2) = 0.884576
# Simpson's: E(2.3) = 0.885213
# Simpson's: E(2.4) = 0.885616
# Simpson's: E(2.5) = 0.885866
# Simpson's: E(2.6) = 0.886018
# Simpson's: E(2.7) = 0.886108
# Simpson's: E(2.8) = 0.886160
# Simpson's: E(2.9) = 0.886190
# Simpson's: E(3.0) = 0.886207

# %% [markdown]
# **Pts /5**

# %% [markdown]
# **c)** Plot and compare the estimates of $E(x)$ you calculated in parts a and b.

# %%
#### PH 322 - HW #3, Q5.3c) - Dan Jang
### Credits to ChatGPT for math-code implementation & plotting help

## Libraries
import numpy as np
import matplotlib.pyplot as plt

def f(t):
    return np.exp(-t**2)


def trapezoidal_integration(f, a, b, n):
    h = (b - a) / n
    x = np.linspace(a, b, n + 1)
    y = f(x)
    return h * (np.sum(y) - (y[0] + y[-1]) / 2)


def simpsons_rule_integration(f, a, b, n):
    if n % 2 == 1:
        raise ValueError("Number of slices must be even for Simpson's rule.")
    h = (b - a) / n
    x = np.linspace(a, b, n + 1)
    y = f(x)
    return h / 3 * (y[0] + y[-1] + 2 * np.sum(y[2:-1:2]) + 4 * np.sum(y[1:-1:2]))


def main():
    ## Constants
    n = 20
    a = 0
    b_values = np.arange(0, 3.1, 0.1)  # Values of x from 0 to 3 in steps of 0.1

    # Calculate integration using trapezoidal rule and Simpson's rule + Plot
    trapezoidal_values = []
    simpsons_values = []
    for b in b_values:
        trapezoidal_values.append(trapezoidal_integration(f, a, b, n))
        simpsons_values.append(simpsons_rule_integration(f, a, b, n))

    # Plot the results
    fig, ax = plt.subplots(figsize=(8, 5))
    ax.semilogy(b_values,
                trapezoidal_values,
                color='blue',
                label='Trapezoidal')
    ax.scatter(b_values, trapezoidal_values, color='blue')

    ax.semilogy(b_values,
                simpsons_values,
                color='red',
                linestyle='dotted',
                label="Simpson's")
    ax.scatter(b_values, simpsons_values, color='red')

    # # Add data point labels for Trapezoidal
    # for i, b in enumerate(b_values):
    #     ax.text(b,
    #             trapezoidal_values[i],
    #             f'{trapezoidal_values[i]:.3f}',
    #             ha='center',
    #             va='top',
    #             fontsize=4)

    # # Add data point labels for Simpsons
    # for i, b in enumerate(b_values):
    #     ax.text(b,
    #             simpsons_values[i],
    #             f'{simpsons_values[i]:.3f}',
    #             ha='center',
    #             va='bottom',
    #             fontsize=4)

    ax.set_xlabel('b')
    ax.set_ylabel('E(b)')
    ax.set_title(
        'PH322, HW #3 - Q4.3b.) Comparison of Trapezoidal and Simpson\'s Rule')
    ax.legend()
    fig.savefig('ph322hw3q53b.png', dpi=150)
    #plt.show()

if __name__ == "__main__":
    main()

# %% [markdown]
# The data points for Simpson's seem to be very, very slightly lower, but is not visible even with a linearized / log scaled x-axis, despite using plt/ax.semilogy to show the very, very small difference in the graph above. I did try using data point labelling, but it was giving me an size error as the image reached several dozen thousand pixels, so I commented that out.

# %% [markdown]
# **Pts /5**

# %% [markdown]
# **Total Exercise Pts /15**

# %% [markdown]
# ## Exercise 5.4
#
# Our ability to resolve detail in astronomical observations is
# limited by the diffraction of light in our telescopes.  Light from stars
# can be treated effectively as coming from a point source at infinity.  When
# such light, with wavelength $\lambda$, passes through the circular aperture
# of a telescope (which we'll assume to have unit radius) and is focused by
# the telescope in the focal plane, it produces not a single dot, but a
# circular diffraction pattern consisting of central spot surrounded by a
# series of concentric rings.  The intensity of the light in this diffraction
# pattern is given by
#
# \begin{equation*}
# I(r) = \biggl( {J_1(kr)\over kr} \biggr)^2,
# \end{equation*}
#
# where $r$ is the distance in the focal plane from the center of the
# diffraction pattern, $k=2\pi/\lambda$, and $J_1(x)$ is a Bessel function.
# The Bessel functions $J_m(x)$ are given by
#
# \begin{equation*}
# J_m(x) = {1\over\pi} \int_0^\pi \cos(m\theta - x\sin\theta) \>d\theta,
# \end{equation*}
#
# where $m$ is a nonnegative integer and $x\ge0$.
#
# **a)** Write a Python function _J(m,x)_ that calculates the value of
#   $J_m(x)$ using Simpson's rule with $N=1000$ points.  Use your
#   function in a program to make a plot, on a single graph, of the Bessel
#   functions $J_0$, $J_1$, and $J_2$ as a function of $x$ from $x=0$ to
#   $x=20$.

# %%
#### PH 322 - HW #3, Q5.4a) - Dan Jang
### Credits to ChatGPT for math-code implementation & plotting help

## Libraries
import numpy as np
import matplotlib.pyplot as plt

# Define the function to integrate
def J(m, x):
    f = lambda t: np.cos(m * t - x * np.sin(t))
    return simpsons_rule_integration(f, 0, np.pi, 1000) / np.pi

# Define the Simpson's rule integration function
def simpsons_rule_integration(f, a, b, n):
    if n % 2 == 1:
        raise ValueError("The number of slices must be even for Simpson's rule.")
    h = (b - a) / n
    x = np.linspace(a, b, n + 1)
    y = f(x)
    return h / 3 * (y[0] + y[-1] + 2 * np.sum(y[2:-1:2]) +
                    4 * np.sum(y[1:-1:2]))

def main():
    ## Constants
    lambda_val = 1.0
    k = 2 * np.pi / lambda_val
    r = 1.0

    # Define the function I(r)
    def I(r, k):
        return (J(1, k * r) / (k * r))**2


    # Create a range of values for x
    x_values = np.linspace(0, 20, 200)

    # Calculate the values of J_0, J_1, and J_2 for each value of x
    J_0_values = [J(0, x) for x in x_values]
    J_1_values = [J(1, x) for x in x_values]
    J_2_values = [J(2, x) for x in x_values]

    # Plot the results
    plt.plot(x_values, J_0_values, label="J_0")
    plt.plot(x_values, J_1_values, label="J_1")
    plt.plot(x_values, J_2_values, label="J_2")
    plt.xlabel("x")
    plt.ylabel("J_m(x)")
    plt.title("PH322, HW #3 - Q5.4a.) Bessel functions (J0, J1, & J2) for 0 <= x <= 20")
    plt.legend()
    plt.show()

if __name__ == "__main__":
    main()

# %% [markdown]
# **Pts /10**

# %% [markdown]
# **b)** Make a second program that makes a density plot of the intensity of
#   the circular diffraction pattern of a point light source with
#   $\lambda=500\,$ nm, in a square region of the focal plane, using the
#   formula given above.  Your picture should cover values of $r$ from zero
#   up to about $1\,\mu$ m.
#
# Hint: The central spot in the
# diffraction pattern is so bright that it may be difficult to see the rings around it on the computer
# screen. If you run into this problem a simple way to deal with it is to use one of the other color
# schemes for density plots described in Section 3.3. The “hot” scheme works well. For a more
# sophisticated solution to the problem, the imshow function has an additional argument vmax
# that allows you to set the value that corresponds to the brightest point in the plot. For instance,
# if you say “imshow(x,vmax=0.1)”, then elements in x with value 0.1, or any greater value, will
# produce the brightest (most positive) color on the screen. By lowering the vmax value, you can
# reduce the total range of values between the minimum and maximum brightness, and hence
# increase the sensitivity of the plot, making subtle details visible. (There is also a vmin argument
# that can be used to set the value that corresponds to the dimmest (most negative) color.) For
# this exercise a value of vmax=0.01 appears to work well.

# %%
#### PH 322 - HW #3, Q5.4b) - Dan Jang
### Credits to ChatGPT for math-code implementation & plotting help

## Libraries
import numpy as np
import matplotlib.pyplot as plt

## Constants
wavelength = 500e-9  # 500 nm
k = 2 * np.pi / wavelength
lambda_val = 1.0
k = 2 * np.pi / lambda_val
r = 1.0


# Define the function to integrate
def J(m, x):
    f = lambda t: np.cos(m * t - x * np.sin(t))
    return simpsons_rule_integration(f, 0, np.pi, 1000) / np.pi


# Define the Simpson's rule integration function
def simpsons_rule_integration(f, a, b, n):
    if n % 2 == 1:
        raise ValueError(
            "The number of slices must be even for Simpson's rule.")
    h = (b - a) / n
    x = np.linspace(a, b, n + 1)
    y = f(x)
    return h / 3 * (y[0] + y[-1] + 2 * np.sum(y[2:-1:2]) +
                    4 * np.sum(y[1:-1:2]))


# Define the function I(r)
def intensity(r, k):
    return (J(1, k * r) / (k * r))**2


def main():
    # Define the grid
    N = 1001
    r_max = 1e-6
    x = np.linspace(-r_max, r_max, N)
    y = np.linspace(-r_max, r_max, N)
    X, Y = np.meshgrid(x, y)
    r = np.sqrt(X**2 + Y**2)

    # Calculate the intensity
    intensity_value = (np.abs((2 * np.pi * J(1, k * r)) / (k * r)))**2

    # Plot the result
    fig, ax = plt.subplots()
    im = ax.imshow(intensity_value,
                   cmap='hot',
                   origin='lower',
                   extent=[-r_max, r_max, -r_max, r_max])
    ax.set_title('PH322, HW #3 - Q5.4b.) Density Plot of Diffraction Pattern')
    ax.set_xlabel('x (m)')
    ax.set_ylabel('y (m)')
    cbar = fig.colorbar(im)
    cbar.ax.set_ylabel('Intensity (W/m^2)')
    plt.show()


if __name__ == "__main__":
    main()
# Out:
# /var/folders/qc/_s6ks9kn1lzd_15y1ydg1ych0000gn/T/ipykernel_3137/937030184.py:49: RuntimeWarning: divide by zero encountered in true_divide
#   intensity_value = (np.abs((2 * np.pi * J(1, k * r)) / (k * r)))**2

# %% [markdown]
# **Pts /10**

# %% [markdown]
# **Total Exercise Pts /20**

# %% [markdown]
# ## Exercise 5.6
#
# a) Write a program, or modify an earlier one, to once more calculate
# the value of the integral $\int_0^2 (x^4 - 2x + 1) \>d x$ from
# Example (5.28), using the trapezoidal rule with $20$ slices, but this time
# have the program also print an estimate of the error on the result,
# calculated using the method of Eq. (5.28).  To do this you will need to
# evaluate the integral twice, once with $N_1=10$ slices and then again with
# $N_2=20$ slices.  Then Eq. (5.28) gives the error.

# %%
#### PH 322 - HW #3, Q5.6a) [from Q5.3a)] - Dan Jang
### Credits to ChatGPT for numpy-code implementation help

## Libraries
import numpy as np

def f(x):
    return (x**4 - 2*x + 1)

def trapezoidal_integration(f, a, b, n):
    h = (b - a) / n
    x = np.linspace(a, b, n + 1)
    y = f(x)
    return h * (np.sum(y) - (y[0] + y[-1]) / 2)

def main():
    ## Constants
    n1 = 10
    n2 = 20
    a = 0
    b_values = np.arange(0, 2.1, 0.1)  # Values of x from 0 to 2 in steps of 0.1

    for b in b_values:
        E_x1 = trapezoidal_integration(f, a, b, n1)
        print(f"Trapezoidal /w 10 Slices [N1]: E({b:.1f}) = {E_x1:.6f}")
        
    for b in b_values:
        E_x2 = trapezoidal_integration(f, a, b, n2)
        print(f"Trapezoidal /w 20 Slices [N2]: E({b:.1f}) = {E_x2:.6f}")
    
    e2 = np.abs((1/3 * (E_x2 - E_x1)))
        
    print("The absolute value of the error, e_2, using Eq. 5.28. was found to be: " + str(e2))
    print("The direct computation of the error was found to be: " + str(np.abs(4.4 - E_x2)))

if __name__ == "__main__":
    main()
# Out:
# Trapezoidal /w 10 Slices [N1]: E(0.0) = 0.000000
# Trapezoidal /w 10 Slices [N1]: E(0.1) = 0.090002
# Trapezoidal /w 10 Slices [N1]: E(0.2) = 0.160065
# Trapezoidal /w 10 Slices [N1]: E(0.3) = 0.210494
# Trapezoidal /w 10 Slices [N1]: E(0.4) = 0.242082
# Trapezoidal /w 10 Slices [N1]: E(0.5) = 0.256354
# Trapezoidal /w 10 Slices [N1]: E(0.6) = 0.255811
# Trapezoidal /w 10 Slices [N1]: E(0.7) = 0.244174
# Trapezoidal /w 10 Slices [N1]: E(0.8) = 0.226627
# Trapezoidal /w 10 Slices [N1]: E(0.9) = 0.210064
# Trapezoidal /w 10 Slices [N1]: E(1.0) = 0.203330
# Trapezoidal /w 10 Slices [N1]: E(1.1) = 0.217465
# Trapezoidal /w 10 Slices [N1]: E(1.2) = 0.265950
# Trapezoidal /w 10 Slices [N1]: E(1.3) = 0.364950
# Trapezoidal /w 10 Slices [N1]: E(1.4) = 0.533558
# Trapezoidal /w 10 Slices [N1]: E(1.5) = 0.794037
# Trapezoidal /w 10 Slices [N1]: E(1.6) = 1.172070
# Trapezoidal /w 10 Slices [N1]: E(1.7) = 1.696995
# Trapezoidal /w 10 Slices [N1]: E(1.8) = 2.402059
# Trapezoidal /w 10 Slices [N1]: E(1.9) = 3.324652
# Trapezoidal /w 10 Slices [N1]: E(2.0) = 4.506560
# Trapezoidal /w 20 Slices [N2]: E(0.0) = 0.000000
# Trapezoidal /w 20 Slices [N2]: E(0.1) = 0.090002
# Trapezoidal /w 20 Slices [N2]: E(0.2) = 0.160064
# Trapezoidal /w 20 Slices [N2]: E(0.3) = 0.210488
# Trapezoidal /w 20 Slices [N2]: E(0.4) = 0.242057
# Trapezoidal /w 20 Slices [N2]: E(0.5) = 0.256276
# Trapezoidal /w 20 Slices [N2]: E(0.6) = 0.255617
# Trapezoidal /w 20 Slices [N2]: E(0.7) = 0.243754
# Trapezoidal /w 20 Slices [N2]: E(0.8) = 0.225809
# Trapezoidal /w 20 Slices [N2]: E(0.9) = 0.208590
# Trapezoidal /w 20 Slices [N2]: E(1.0) = 0.200833
# Trapezoidal /w 20 Slices [N2]: E(1.1) = 0.213444
# Trapezoidal /w 20 Slices [N2]: E(1.2) = 0.259737
# Trapezoidal /w 20 Slices [N2]: E(1.3) = 0.355679
# Trapezoidal /w 20 Slices [N2]: E(1.4) = 0.520129
# Trapezoidal /w 20 Slices [N2]: E(1.5) = 0.775077
# Trapezoidal /w 20 Slices [N2]: E(1.6) = 1.145888
# Trapezoidal /w 20 Slices [N2]: E(1.7) = 1.661543
# Trapezoidal /w 20 Slices [N2]: E(1.8) = 2.354878
# Trapezoidal /w 20 Slices [N2]: E(1.9) = 3.262827
# Trapezoidal /w 20 Slices [N2]: E(2.0) = 4.426660
# The absolute value of the error, e_2, using Eq. 5.28. was found to be: 0.026633333333333137
# The direct computation of the error was found to be: 0.026660000000000572

# %% [markdown]
# **Estimate of error using Eq. 5.28:**
#
# How does the error calculated in this manner compare with a direct computation of the error as
# the difference between your value for the integral and the true value
# of 4.4?  Why do the two not agree perfectly?
#
# **Explanation:**
#
# Such difference as shown above is due to the direct computation of the error not accounting for the half-n, N1 = 10 integralization step through trapezoidal rule as shown above, whereas 5.28.) does account for it as part of the error calculations.

# %% [markdown]
# **Pts /10**

# %% [markdown]
# b) Also calculate the error using the *Euler-Maclaurin formula* of Eq. (5.20). How does this compare with your other two estimates of the error?

# %%
#### PH 322 - HW #3, Q5.6b) [from Q5.6a) & Q5.3a)] - Dan Jang
### Credits to ChatGPT for numpy-code implementation help

## Libraries
import numpy as np

def f(x):
    return (x**4 - 2*x + 1)

def trapezoidal_integration(f, a, b, n):
    h = (b - a) / n
    x = np.linspace(a, b, n + 1)
    y = f(x)
    return h * (np.sum(y) - (y[0] + y[-1]) / 2)

def euler_maclaurin_eq5_20(f, a, b, n1, n2):
    # Constants
    h1 = (b - a) / n1
    h2 = (b - a) / n2
    
    # Integration
    x1 = np.linspace(a, b, n1 + 1)
    y1 = f(x1)
    E_x1 = h1 * (np.sum(y1) - (y1[0] + y1[-1]) / 2)
    
    x2 = np.linspace(a, b, n2 + 1)
    y2 = f(x2)
    E_x2 = h2 * (np.sum(y2) - (y2[0] + y2[-1]) / 2)
    
    # Error
    e = (1/12) * (h2**2) * (E_x1 - E_x2)
    return e

def main():
    ## Constants
    n1 = 10
    n2 = 20
    a = 0
    b_values = np.arange(0, 2.1, 0.1)  # Values of x from 0 to 2 in steps of 0.1

    for b in b_values:
        E_x1 = trapezoidal_integration(f, a, b, n1)
        print(f"Trapezoidal /w 10 Slices [N1]: E({b:.1f}) = {E_x1:.6f}")
        
    for b in b_values:
        E_x2 = trapezoidal_integration(f, a, b, n2)
        print(f"Trapezoidal /w 20 Slices [N2]: E({b:.1f}) = {E_x2:.6f}")
        
    for b in b_values:
        e = euler_maclaurin_eq5_20(f, a, b, n1, n2)
        print(f"Euler-Maclaurin Error [N1={n1}, N2={n2}]: E({b:.1f}) = {e:.6f}")
        
    #print("The absolute value of the error, e_2, using Eq. 5.28. was found to be: " + str(e))
    #print("The direct computation of the error was found to be: " + str(np.abs(4.4 - E_x2)))
    #print("The Euler-Maclaurin estimate of the error, e, using Eq. 5.20. was found to be: " + str(euler_maclaurin_eq5_20()))

if __name__ == "__main__":
    main()
# Out:
# Trapezoidal /w 10 Slices [N1]: E(0.0) = 0.000000
# Trapezoidal /w 10 Slices [N1]: E(0.1) = 0.090002
# Trapezoidal /w 10 Slices [N1]: E(0.2) = 0.160065
# Trapezoidal /w 10 Slices [N1]: E(0.3) = 0.210494
# Trapezoidal /w 10 Slices [N1]: E(0.4) = 0.242082
# Trapezoidal /w 10 Slices [N1]: E(0.5) = 0.256354
# Trapezoidal /w 10 Slices [N1]: E(0.6) = 0.255811
# Trapezoidal /w 10 Slices [N1]: E(0.7) = 0.244174
# Trapezoidal /w 10 Slices [N1]: E(0.8) = 0.226627
# Trapezoidal /w 10 Slices [N1]: E(0.9) = 0.210064
# Trapezoidal /w 10 Slices [N1]: E(1.0) = 0.203330
# Trapezoidal /w 10 Slices [N1]: E(1.1) = 0.217465
# Trapezoidal /w 10 Slices [N1]: E(1.2) = 0.265950
# Trapezoidal /w 10 Slices [N1]: E(1.3) = 0.364950
# Trapezoidal /w 10 Slices [N1]: E(1.4) = 0.533558
# Trapezoidal /w 10 Slices [N1]: E(1.5) = 0.794037
# Trapezoidal /w 10 Slices [N1]: E(1.6) = 1.172070
# Trapezoidal /w 10 Slices [N1]: E(1.7) = 1.696995
# Trapezoidal /w 10 Slices [N1]: E(1.8) = 2.402059
# Trapezoidal /w 10 Slices [N1]: E(1.9) = 3.324652
# Trapezoidal /w 10 Slices [N1]: E(2.0) = 4.506560
# Trapezoidal /w 20 Slices [N2]: E(0.0) = 0.000000
# Trapezoidal /w 20 Slices [N2]: E(0.1) = 0.090002
# Trapezoidal /w 20 Slices [N2]: E(0.2) = 0.160064
# Trapezoidal /w 20 Slices [N2]: E(0.3) = 0.210488
# Trapezoidal /w 20 Slices [N2]: E(0.4) = 0.242057
# Trapezoidal /w 20 Slices [N2]: E(0.5) = 0.256276
# Trapezoidal /w 20 Slices [N2]: E(0.6) = 0.255617
# Trapezoidal /w 20 Slices [N2]: E(0.7) = 0.243754
# Trapezoidal /w 20 Slices [N2]: E(0.8) = 0.225809
# Trapezoidal /w 20 Slices [N2]: E(0.9) = 0.208590
# Trapezoidal /w 20 Slices [N2]: E(1.0) = 0.200833
# Trapezoidal /w 20 Slices [N2]: E(1.1) = 0.213444
# Trapezoidal /w 20 Slices [N2]: E(1.2) = 0.259737
# Trapezoidal /w 20 Slices [N2]: E(1.3) = 0.355679
# Trapezoidal /w 20 Slices [N2]: E(1.4) = 0.520129
# Trapezoidal /w 20 Slices [N2]: E(1.5) = 0.775077
# Trapezoidal /w 20 Slices [N2]: E(1.6) = 1.145888
# Trapezoidal /w 20 Slices [N2]: E(1.7) = 1.661543
# Trapezoidal /w 20 Slices [N2]: E(1.8) = 2.354878
# Trapezoidal /w 20 Slices [N2]: E(1.9) = 3.262827
# Trapezoidal /w 20 Slices [N2]: E(2.0) = 4.426660
# Euler-Maclaurin Error [N1=10, N2=20]: E(0.0) = 0.000000
# Euler-Maclaurin Error [N1=10, N2=20]: E(0.1) = 0.000000
# Euler-Maclaurin Error [N1=10, N2=20]: E(0.2) = 0.000000
# Euler-Maclaurin Error [N1=10, N2=20]: E(0.3) = 0.000000
# Euler-Maclaurin Error [N1=10, N2=20]: E(0.4) = 0.000000
# Euler-Maclaurin Error [N1=10, N2=20]: E(0.5) = 0.000000
# Euler-Maclaurin Error [N1=10, N2=20]: E(0.6) = 0.000000
# Euler-Maclaurin Error [N1=10, N2=20]: E(0.7) = 0.000000
# Euler-Maclaurin Error [N1=10, N2=20]: E(0.8) = 0.000000
# Euler-Maclaurin Error [N1=10, N2=20]: E(0.9) = 0.000000
# Euler-Maclaurin Error [N1=10, N2=20]: E(1.0) = 0.000001
# Euler-Maclaurin Error [N1=10, N2=20]: E(1.1) = 0.000001
# Euler-Maclaurin Error [N1=10, N2=20]: E(1.2) = 0.000002
# Euler-Maclaurin Error [N1=10, N2=20]: E(1.3) = 0.000003
# Euler-Maclaurin Error [N1=10, N2=20]: E(1.4) = 0.000005
# Euler-Maclaurin Error [N1=10, N2=20]: E(1.5) = 0.000009
# Euler-Maclaurin Error [N1=10, N2=20]: E(1.6) = 0.000014
# Euler-Maclaurin Error [N1=10, N2=20]: E(1.7) = 0.000021
# Euler-Maclaurin Error [N1=10, N2=20]: E(1.8) = 0.000032
# Euler-Maclaurin Error [N1=10, N2=20]: E(1.9) = 0.000046
# Euler-Maclaurin Error [N1=10, N2=20]: E(2.0) = 0.000067

# %% [markdown]
# **Estimate of error using the Euler-Maclaurin formula:** Euler-Maclaurin Error [N1=10, N2=20]: E(2.0) = 0.000067
#
# **Explanation:**
#
# The error is calculated using Eq 5.20, where it describes "only the first term in the Euler-Maclaurin formula", where it uses the leading order in h, with the value of the terms dropped when using the trapezoidal rule. It seems similar to the e2 formula (Eq 5.28), however, we evaluate at each step of E(n), for & with both integrals, thus, we get a specific error that seems to be more accurate than the previous two error calculation methods we've used (vs. direct computation & Eq. 5.28.) (Newman, 2012, ch. 5, p. 12)

# %% [markdown]
# **Pts /5**

# %% [markdown]
# **Total Exercise Pts /15**

# %% [markdown]
# **Total Pts /75**
